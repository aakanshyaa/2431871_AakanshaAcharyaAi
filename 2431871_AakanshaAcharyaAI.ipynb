# %% [markdown]
# # 1.
# 3 Tasks - To - Do:
# Please Solve all the Problems as instructed:
# 3.1 Problem -
# 1: Getting Started with Data Exploration - Some Warm up Exercises:
# 1. Data Exploration and Understanding:
# • Dataset Overview:
# 1. Load the dataset and display the first 10 rows.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
readcsv = pd.read_csv("/content/drive/MyDrive/WHR-2024-5CS037.csv")
df = pd.DataFrame(readcsv)
df
# Out:
#          Country name  score  Log GDP per capita  Social support  \
# 0             Finland  7.741               1.844           1.572
# 1             Denmark  7.583               1.908           1.520
# 2             Iceland  7.525               1.881           1.617
# 3              Sweden  7.344               1.878           1.501
# 4              Israel  7.341               1.803           1.513
# ..                ...    ...                 ...             ...
# 138  Congo (Kinshasa)  3.295               0.534           0.665
# 139      Sierra Leone  3.245               0.654           0.566
# 140           Lesotho  3.186               0.771           0.851
# 141           Lebanon  2.707               1.377           0.577
# 142       Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.695                         0.859       0.142
# 1                      0.699                         0.823       0.204
# 2                      0.718                         0.819       0.258
# 3                      0.724                         0.838       0.221
# 4                      0.740                         0.641       0.153
# ..                       ...                           ...         ...
# 138                    0.262                         0.473       0.189
# 139                    0.253                         0.469       0.181
# 140                    0.000                         0.523       0.082
# 141                    0.556                         0.173       0.068
# 142                    0.242                         0.000       0.091
#
#      Perceptions of corruption  Dystopia + residual
# 0                        0.546                2.082
# 1                        0.548                1.881
# 2                        0.182                2.050
# 3                        0.524                1.658
# 4                        0.193                2.298
# ..                         ...                  ...
# 138                      0.072                1.102
# 139                      0.053                1.068
# 140                      0.085                0.875
# 141                      0.029               -0.073
# 142                      0.088                0.672
#
# [143 rows x 9 columns]

# %%
# import pandas as pd
# df = pd.read_csv('/content/drive/MyDrive/WHR-2024-5CS037.csv')
df.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 3                    0.724                         0.838       0.221
# 4                    0.740                         0.641       0.153
# 5                    0.706                         0.725       0.247
# 6                    0.704                         0.835       0.224
# 7                    0.708                         0.801       0.146
# 8                    0.747                         0.759       0.173
# 9                    0.692                         0.756       0.225
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050
# 3                      0.524                1.658
# 4                      0.193                2.298
# 5                      0.372                1.906
# 6                      0.484                1.586
# 7                      0.432                1.540
# 8                      0.498                1.488
# 9                      0.323                1.745

# %% [markdown]
# # 2. Identify the number of rows and columns in the dataset.

# %%
reader = pd.read_csv("/content/drive/MyDrive/WHR-2024-5CS037.csv")
data_frame = pd.DataFrame(reader)
rows,columns =data_frame.shape
print(f"Rows:{rows} Columns:{columns}")
# Out:
# Rows:143 Columns:9

# %% [markdown]
# # 3. List all the columns and their data types.

# %%
# readcsv = pd.read_csv("/content/drive/MyDrive/WHR-2024-5CS037.csv")
# df = pd.DataFrame(readcsv)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country name                  143 non-null    object
#  1   score                         143 non-null    float64
#  2   Log GDP per capita            140 non-null    float64
#  3   Social support                140 non-null    float64
#  4   Healthy life expectancy       140 non-null    float64
#  5   Freedom to make life choices  140 non-null    float64
#  6   Generosity                    140 non-null    float64
#  7   Perceptions of corruption     140 non-null    float64
#  8   Dystopia + residual           140 non-null    float64
# dtypes: float64(8), object(1)
# memory usage: 10.2+ KB

# %% [markdown]
# # • Basic Statistics:
# # 1. Calculate the mean, median, and standard deviation for the Score column

# %%
# reader = pd.read_csv("/content/drive/MyDrive/WHR-2024-5CS037.csv")
# data_frame = pd.DataFrame(reader)
score_mean = df['score'].mean()
score_median = df['score'].median()
std_dev =df['score'].std()
print(f"Mean:{score_mean},Median:{score_median},Standard deviation:{std_dev}")
# Out:
# Mean:5.52758041958042,Median:5.785,Standard deviation:1.1707165099442995

# %% [markdown]
# # • Basic Statistics:
# # 2. Identify the country with the highest and lowest happiness scores.

# %%
# reader = pd.read_csv("/content/drive/MyDrive/WHR-2024-5CS037.csv")
# data_frame = pd.DataFrame(reader)
# highest_score = df['score'].max()
# lowest_score = df['score'].min()
country_highest = df.loc[data_frame['score'].idxmax(),'Country name']
country_lowest = df.loc[data_frame['score'].idxmin(),'Country name']
country_highest,country_lowest
# Out:
# ('Finland', 'Afghanistan')

# %% [markdown]
# # • Missing Values:
# # 1. Check if there are any missing values in the dataset. If so, display the total count for each column

# %%
# reader = pd.read_csv("/content/drive/MyDrive/WHR-2024-5CS037.csv")
# data_frame = pd.DataFrame(reader)
null_values = df.isnull().sum()
null_values
# Out:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# # • Filtering and Sorting:
# # 1. Filter the dataset to show only the countries with a Score greater than 7.5.

# %%
# reader = pd.read_csv("/content/drive/MyDrive/WHR-2024-5CS037.csv")
# data_frame = pd.DataFrame(reader)
filtered = df[df['score']>=7.5]
filtered
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050

# %% [markdown]
# # • Filtering and Sorting:
# # 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# # top 10 rows.

# %%
# reader = pd.read_csv("/content/drive/MyDrive/WHR-2024-5CS037.csv")
# data_frame = pd.DataFrame(reader)
filtered= df[df['score']>=7.5]
sorted_gdp = filtered.sort_values('Log GDP per capita', ascending=False)
top_10_countries = sorted_gdp.head()
top_10_countries
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual
# 1                      0.548                1.881
# 2                      0.182                2.050
# 0                      0.546                2.082

# %% [markdown]
# # • Adding New Columns:
# # 1. Create a new column called Happiness Category that categorizes countries into three categories
# # based on their Score:
# # Low − (Score < 4)
# # Medium − (4 ≤ Score ≤ 6)
# # High − (Score > 6)

# %%
# reader = pd.read_csv("/content/drive/MyDrive/WHR-2024-5CS037.csv")
# data_frame = pd.DataFrame(reader)
def cat(score):
    if score <4:
        return 'Low'
    elif score <=6:
        return 'Medium'
    else:
        return 'High'

df['Happiness_Category']=df['score'].apply(cat)
count = df['Happiness_Category'].value_counts()
count
# Out:
# Happiness_Category
# Medium    70
# High      56
# Low       17
# Name: count, dtype: int64

# %% [markdown]
# # 2. Data Visualizations:
# # • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.

# %%
import matplotlib.pyplot as plt
# reader = pd.read_csv("/content/drive/MyDrive/WHR-2024-5CS037.csv")
# data_frame = pd.DataFrame(reader)
score10 = df.sort_values('score', ascending= False)
top10 = score10.head(10)
plt.figure(figsize=(10,6))
plt.xlabel('Country Name')
plt.ylabel('Score')
plt.bar(top10['Country name'],top10['score'],color ='pink')
plt.title("Happiness Country")
plt.tight_layout()
plt.show()

# %% [markdown]
# # • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.

# %%
# reader = pd.read_csv("/content/drive/MyDrive/WHR-2024-5CS037.csv")
# data_frame = pd.DataFrame(reader)
top_10_unhappiest = df.sort_values('score',ascending=True)
top_10 = top_10_unhappiest.head(10)
plt.figure(figsize=(10,6))
plt.xlabel('Country Name')
plt.ylabel('Score')
plt.plot(top_10['Country name'],top_10['score'],color ='pink',ls='-',marker ='o')
plt.title("Happiness Country")
plt.tight_layout()
plt.show()

# %% [markdown]
# # • Plot a histogram for the Score column to show its distribution and also interpret.

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(10, 6))
plt.hist(df['score'] ,bins=10, color='pink')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram Example')
plt.tight_layout()
plt.show()

# %% [markdown]
# # • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
import pandas as pd
import matplotlib.pyplot as plt
reader = pd.read_csv("/content/drive/MyDrive/WHR-2024-5CS037.csv")
data_frame = pd.DataFrame(reader)
gdp = data_frame['Log GDP per capita']
score = data_frame['score']
plt.figure(figsize=(10,6))
plt.scatter(x=gdp,y=score,color='pink',marker='o')
plt.xlabel('GDP per Capita')
plt.ylabel('Score')
plt.title('Scatter Plot')
plt.tight_layout()
plt.show()

# %%
# 3.2 Problem - 2 - Some Advance Data Exploration Task:
# Task - 1 - Setup Task - Preparing the South-Asia Dataset:
# Steps:
# 1. Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",

# "Maldives", "Nepal", "Pakistan", "Srilanka"]

# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
# 3. Save the filtered dataframe as separate CSV files for future use.
import pandas as pd
readcsv = pd.read_csv("/content/drive/MyDrive/WHR-2024-5CS037.csv")
df = pd.DataFrame(readcsv)
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
"Maldives", "Nepal", "Pakistan", "Sri Lanka"]
filtered_data = df[df['Country name'].isin(south_asian_countries)]
filtered_data.to_csv('filtered_data.csv', index=False)

# %%
# Task - 2 - Composite Score Ranking:
# Tasks:
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:

# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support

# + 0.30 × Healthy Life Expectancy
# 2. Rank the South Asian countries based on the Composite Score in descending order.
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.
import pandas as pd
import matplotlib.pyplot as plt
read = pd.read_csv("/content/filtered_data.csv")
df = pd.DataFrame(read)
df['Composite Score'] = 0.40*df['Log GDP per capita']+ 0.30*df['Social support']+0.30*df['Healthy life expectancy']
sort_data= df.sort_values(by='Composite Score',ascending =False)
top_5=sort_data.head(5)
x= top_5['Country name']
y=top_5['Composite Score']
plt.xlabel("Country Name")
plt.ylabel("Composite Score")
plt.bar(x,y,color = "pink")
plt.tight_layout()
plt.show()

# %%
# Task - 3 - Outlier Detection:
# Tasks:
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
# 2. Define outliers using the 1.5 × IQR rule.
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
read = pd.read_csv("/content/filtered_data.csv")
df = pd.DataFrame(read)
def outlier(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = (data < lower_bound) | (data > upper_bound)
    return outliers

outlier_score = outlier(df['score'])
outlier_gdp = outlier(df['Log GDP per capita'])
# print(outlier_score,outlier_gdp)
combined = outlier_score|outlier_gdp

plt.scatter(df['Log GDP per capita'],df['score'],color = 'pink',marker='o')
plt.scatter(df.loc[combined,'Log GDP per capita'],df.loc[combined,'score'],color = 'red',marker='o')
plt.xlabel('GDP per Capita')
plt.ylabel('Score')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sb
read = pd.read_csv("/content/filtered_data.csv")
df=pd.DataFrame(read)
freedom = df['Freedom to make life choices']
generosity = df['Generosity']
score = df['score']
corr_freedom=freedom.corr(score,method ='pearson')
corr_generosity=generosity.corr(score,method='pearson')
print(f"Correlation between freedom and score:{corr_freedom}")
print(f"Correlation between generosity and score:{corr_generosity}")
plt.figure(figsize=(8,5))
sb.regplot(x='Freedom to make life choices',y='score',ci=None,data=df, scatter_kws ={'color':'blue'},line_kws={'color':'red'})
plt.xlabel('Freedom to make life choices')
plt.ylabel('Score')
plt.tight_layout()
plt.show()
plt.figure(figsize=(8, 5))
sb.regplot(x='Generosity',y='score',data=df, ci=None,scatter_kws ={'color':'green'},line_kws={'color':'skyblue'})
plt.xlabel('Generosity')
plt.ylabel('Score')
plt.tight_layout()
plt.show()
# Out:
# Correlation between freedom and score:0.8005185224163315
# Correlation between generosity and score:0.874512371253192

# %%
import pandas as pd
# reader = pd.read_csv("/content/filtered_data.csv")
# SADF = pd.DataFrame(reader)
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.
df['GDP-Score']=df['Log GDP per capita']-df['score']
# 2. Rank the South Asian countries by this gap in both ascending and descending order.
sort_by_gap_asc = df.sort_values(by = 'GDP-Score',ascending = True)
sort_by_gap_des=df.sort_values(by = 'GDP-Score',ascending = False)
sort_by_gap_asc.head(3)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
#
#    Perceptions of corruption  Dystopia + residual  GDP-Score
# 0                      0.115                1.783     -4.193
# 1                      0.074                1.907     -3.588
# 2                      0.122                0.756     -2.888

# %%
sort_by_gap_des.head(3)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 5  Afghanistan  1.721               0.628           0.000
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 5                    0.242                         0.000       0.091
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
#
#    Perceptions of corruption  Dystopia + residual  GDP-Score
# 5                      0.088                0.672     -1.093
# 3                      0.031                0.014     -2.537
# 4                      0.167                0.919     -2.764

# %%
import pandas as pd
reader = pd.read_csv("/content/drive/MyDrive/WHR-2024-5CS037.csv")
data_frame = pd.DataFrame(reader)
middle_east_countries = ["Bahrain", "Iran", "Iraq", "Israel", "Jordan",
"Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
"United Arab Emirates", "Yemen"]
filtered_data = data_frame[data_frame['Country name'].isin(middle_east_countries)]
middle_east_datas= pd.DataFrame(filtered_data)
middle_east_datas
# Out:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# 12                     0.661                         0.827       0.200
# 21                     0.563                         0.815       0.209
# 27                     0.511                         0.787       0.114
# 61                       NaN                           NaN         NaN
# 91                     0.498                         0.425       0.141
# 99                     0.571                         0.366       0.235
# 124                    0.594                         0.593       0.059
# 132                    0.293                         0.362       0.080
# 141                    0.556                         0.173       0.068
#
#      Perceptions of corruption  Dystopia + residual
# 4                        0.193                2.298
# 12                       0.172                1.884
# 21                       0.258                1.741
# 27                       0.188                1.790
# 61                         NaN                  NaN
# 91                       0.048                1.809
# 99                       0.123                1.057
# 124                      0.189                0.504
# 132                      0.113                0.760
# 141                      0.029               -0.073

# %%
import pandas as pd
# reader = pd.read_csv("C:\\Users\\user\\Desktop\\filtered.csv")
# SADF = pd.DataFrame(reader)
mean_middle_east =middle_east_datas['score'].mean()
mean_df = df['score'].mean()
std_dev=middle_east_datas['score'].std()
std_df = df['score'].std()
print("Mean scores for the region")
print(mean_middle_east,mean_df)
print("Standard deviation for the region")
print(std_dev,std_df)
if(mean_middle_east>mean_df):
    print("middle east has the high happiness score")
else:
    print("South East has the high happiness score")
# Out:
# Mean scores for the region
# 5.412100000000001 3.895666666666667
# Standard deviation for the region
# 1.5662011684327144 1.1770690152521504
# middle east has the high happiness score

# %%
# 2. Top and Bottom Performers:
# • Identify the top 3 and bottom 3 countries in each region based on the score.
# • Plot bar charts comparing these charts.
import pandas as pd
import matplotlib.pyplot as plt
reader = pd.read_csv("/content/filtered_data.csv")
southasia = pd.DataFrame(reader)
middle_east = pd.DataFrame(filtered_data)
middle_east_top_3 = middle_east.sort_values(by='score', ascending=False)
southasian_top_3=southasia.sort_values(by='score',ascending=False)
print("========================For Middle East Countries=========================")
print(middle_east_top_3['Country name'].head(3))
print(middle_east_top_3['Country name'].tail(3))
print("========================for South Asian countries============================")
print(southasian_top_3['Country name'].head(3))
print(southasian_top_3['Country name'].tail(3))
x= southasian_top_3['Country name'].head(3)
y= southasian_top_3['score'].head(3)
plt.bar(x,y,color='pink')
plt.xlabel("Country for top south asian")
plt.ylabel("Score for top south asian")
plt.show()
x= southasian_top_3['Country name'].tail(3)
y= southasian_top_3['score'].tail(3)
plt.bar(x,y,color='pink')
plt.xlabel("Country for bottom south asian")
plt.ylabel("Score for bottom south asian")
plt.show()
x= middle_east_top_3['Country name'].head(3)
y= middle_east_top_3['score'].head(3)
plt.bar(x,y,color='pink')
plt.xlabel("Country for top middle east")
plt.ylabel("Score for top middle east")
plt.show()
x= middle_east_top_3['Country name'].tail(3)
y= middle_east_top_3['score'].tail(3)
plt.bar(x,y,color='pink')
plt.xlabel("Country for bottom middle east")
plt.ylabel("Score for bottom middle east")
plt.show()
# Out:
# ========================For Middle East Countries=========================
# 4                   Israel
# 12                  Kuwait
# 21    United Arab Emirates
# Name: Country name, dtype: object
# 124     Jordan
# 132      Yemen
# 141    Lebanon
# Name: Country name, dtype: object
# ========================for South Asian countries============================
# 0       Nepal
# 1    Pakistan
# 2       India
# Name: Country name, dtype: object
# 3      Sri Lanka
# 4     Bangladesh
# 5    Afghanistan
# Name: Country name, dtype: object

# %%
# 4. Happiness Disparity:
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
SADF_range = southasia['score'].max()-southasia['score'].min()
middle_east_range = middle_east['score'].max()-middle_east['score'].min()
SADF_CV = southasia['score'].std()/southasia['score'].mean()
middle_east_cv=middle_east['score'].std()/southasia['score'].mean()
print("Ranges: ",SADF_range,middle_east_range)
print("Coeffecient of variations: ",SADF_CV,middle_east_cv)
# • Which region has greater variability in happiness?
# Answer: According to the result for the coefficient of variation in both the regions the south asian country has a variation of 0.33 and that of middle east is 0.40 so the middle east has the greater variability in happiness.
# Out:
# Ranges:  3.4370000000000003 4.634
# Coeffecient of variations:  0.3021482883337427 0.4020367506886406

# %%
# 5. Correlation Analysis:
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and
# Generosity within each region.
# • Create scatter plots to visualize and interpret the relationships.
import matplotlib.pyplot as plt
import seaborn as sns
middle_east_score = middle_east['score']
middle_east_freedom =middle_east['Freedom to make life choices']
middle_east_generosity = middle_east['Generosity']
southasia_score =southasia['score']
southasia_freedom =southasia['Freedom to make life choices']
southasia_generosity=southasia['Generosity']
corr_Sadf = southasia_score.corr(southasia_freedom,method='pearson')
corr_generosity=southasia_score.corr(southasia_generosity,method='pearson')
print(corr_Sadf,corr_generosity)
corr_middle_east = middle_east_score.corr(middle_east_freedom,method='pearson')
corr_middle_east_generosity = middle_east_score.corr(middle_east_generosity,method='pearson')
print(corr_middle_east,corr_middle_east)
# Scatter plot for Region 1: Score vs Freedom to Make Life Choices
plt.figure(figsize=(8, 6))
sns.scatterplot(data=middle_east, y=middle_east_score, x=middle_east_freedom, color='blue', label='Middle east region')
plt.title('Score vs Freedom to Make Life Choices (Middle east region)')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')
plt.legend()
plt.show()
# Scatter plot for Region 1: Score vs Generosity
plt.figure(figsize=(8, 6))
sns.scatterplot(data=middle_east, y=middle_east_score, x=middle_east_generosity, color='green', label='Middle east region')
plt.title('Score vs Generosity (Middle East Region)')
plt.xlabel('Generosity')
plt.ylabel('Score')
plt.legend()
plt.show()

# Repeat for Region 2
plt.figure(figsize=(8, 6))
sns.scatterplot(data=southasia, y=southasia_score, x=southasia_freedom, color='red', label='South Asian region')
plt.title('Score vs Freedom to Make Life Choices (South Asian Region)')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')
plt.legend()
plt.show()

plt.figure(figsize=(8, 6))
sns.scatterplot(data=southasia, y=southasia_score, x=southasia_generosity, color='purple', label='South Asian region')
plt.title('Score vs Generosity (South Asian Region)')
plt.xlabel('Generosity')
plt.ylabel('Score')
plt.legend()
plt.show()
# Out:
# 0.8005185224163315 0.874512371253192
# 0.8632202433827544 0.8632202433827544

# %%
# 6. Outlier Detection:
# • Identify outlier countries in both regions based on Score and GDP per Capita.
# • Plot these outliers and discuss their implications.
middle_east_score = middle_east_datas['score']
middle_east_gdp =middle_east_datas['Log GDP per capita']
SADF_score =southasia['score']
SADF_gdp =southasia['Log GDP per capita']
def outliers(col_name):
    Q1 = col_name.quantile(0.25)
    Q3 = col_name.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return (col_name < lower_bound) | (col_name > upper_bound)
middle_east_outliers_scr =outliers(middle_east_score)
middle_east_outliers_gdp =outliers(middle_east_gdp)
SADF_outliers_scr = outliers(SADF_score)
SADF_outliers_gdp = outliers(SADF_gdp)
plt.figure(figsize=(10, 6))
plt.scatter( middle_east_datas['Log GDP per capita'], middle_east_datas['score'],label='Non-Outliers', c='blue', alpha=0.5)
plt.scatter(middle_east_datas[middle_east_outliers_scr]['score'],
            middle_east_datas[middle_east_outliers_scr]['Log GDP per capita'],
            c='orange', label='Score Outliers', marker='o', edgecolors='black', s=100)
plt.scatter(middle_east_datas[middle_east_outliers_gdp]['score'],
            middle_east_datas[middle_east_outliers_gdp]['Log GDP per capita'],
            c='red', label='GDP Outliers', marker='x', s=100)
plt.title("Middle East: Outliers in Score and Log GDP per Capita")
plt.xlabel("Score")
plt.ylabel("Log GDP per Capita")
plt.legend()
plt.show()
plt.figure(figsize=(10, 6))
plt.scatter(southasia['Log GDP per capita'],southasia['score'],  label='Non-Outliers', c='green', alpha=0.5)
plt.scatter(southasia[SADF_outliers_scr]['score'],
           southasia[SADF_outliers_scr]['Log GDP per capita'],
            c='orange', label='Score Outliers', marker='o', edgecolors='black', s=100)
plt.scatter(southasia[SADF_outliers_gdp]['score'],
            southasia[SADF_outliers_gdp]['Log GDP per capita'],
            c='red', label='GDP Outliers', marker='x', s=100)
plt.title("SADF: Outliers in Score and Log GDP per Capita")
plt.xlabel("Score")
plt.ylabel("Log GDP per Capita")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
south_asian_scores = southasia['score']
middle_east_scores = middle_east['score']
import pandas as pd
data = pd.DataFrame({
    'Score': pd.concat([south_asian_scores, middle_east_scores]),
    'Region': ['South Asia'] * len(south_asian_scores) + ['Middle East'] * len(middle_east_scores)
})
plt.figure(figsize=(10, 6))
sns.boxplot(x='Region', y='Score', data=data, palette='Set1')
plt.xlabel("Region")
plt.ylabel("Score")
plt.title("Comparison of Score Distribution Between South Asia and Middle East")
plt.tight_layout()
plt.show()
# A box plot gives the distribution of data for a given group including the median,interquartile,outliers,etc.
# Out:
# <ipython-input-138-3d78bdd590d8>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Region', y='Score', data=data, palette='Set1')
